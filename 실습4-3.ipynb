# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url) 
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
songs = soup.select('table > tbody > tr')

# %%
song_data = []
rank = 1
for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text
    song_data.append(['Genie', rank, title, singer])
    rank += 1

# %%
import pandas as pd

columns =  ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data)
pd_data
# Out:
#         0   1                                           2                        3
# 0   Genie   1                                       To. X             태연 (TAEYEON)
# 1   Genie   2                                       Drama                    aespa
# 2   Genie   3                               Perfect Night       LE SSERAFIM (르세라핌)
# 3   Genie   4                                    헤어지자 말해요                      박재정
# 4   Genie   5                                      Baddie                IVE (아이브)
# 5   Genie   6                                    Love Lee                AKMU (악뮤)
# 6   Genie   7                                      후라이의 꿈                AKMU (악뮤)
# 7   Genie   8                                        I AM                IVE (아이브)
# 8   Genie   9                                    You & Me              제니 (JENNIE)
# 9   Genie  10                                   사랑은 늘 도망가                      임영웅
# 10  Genie  11                                 사막에서 꽃을 피우듯               우디 (Woody)
# 11  Genie  12            Seven (Feat. Latto) (Clean Ver.)                       정국
# 12  Genie  13                                          인사                       범진
# 13  Genie  14                                         ETA                 NewJeans
# 14  Genie  15          Smoke (Prod. by Dynamicduo & Padi)            다이나믹 듀오 & 이영지
# 15  Genie  16                                      비의 랩소디                      임재현
# 16  Genie  17                                    우리들의 블루스                      임영웅
# 17  Genie  18                                   Super Shy                 NewJeans
# 18  Genie  19                                      모래 알갱이                      임영웅
# 19  Genie  20                                   이제 나만 믿어요                      임영웅
# 20  Genie  21                              퀸카 (Queencard)                  (여자)아이들
# 21  Genie  22                                 다시 만날 수 있을까                      임영웅
# 22  Genie  23                                       Ditto                 NewJeans
# 23  Genie  24                                     사건의 지평선              윤하 (YOUNHA)
# 24  Genie  25  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  너드커넥션 (Nerd Connection)
# 25  Genie  26                                      사랑인가 봐         멜로망스 (MeloMance)
# 26  Genie  27                                  Either Way                IVE (아이브)
# 27  Genie  28                                    Hype Boy                 NewJeans
# 28  Genie  29                                   Do or Die                      임영웅
# 29  Genie  30                                         무지개                      임영웅
# 30  Genie  31             All I Want for Christmas Is You             Mariah Carey
# 31  Genie  32                                  London Boy                      임영웅
# 32  Genie  33                                    Polaroid                      임영웅
# 33  Genie  34                                       심 (心)                 DK (디셈버)
# 34  Genie  35                                         아버지                      임영웅
# 35  Genie  36                                         예뻤어              DAY6 (데이식스)
# 36  Genie  37               I Don't Think That I Like Her             Charlie Puth
# 37  Genie  38                                     잠시라도 우리                 성시경 & 나얼
# 38  Genie  39                                   A bientot                      임영웅
# 39  Genie  40                                Fast Forward                      전소미
# 40  Genie  41                               Santa Tell Me            Ariana Grande
# 41  Genie  42                                      Kitsch                IVE (아이브)
# 42  Genie  43                                        인생찬가                      임영웅
# 43  Genie  44                    잘 지내자, 우리 (여름날 우리 X 로이킴)                      로이킴
# 44  Genie  45                       이브, 프시케 그리고 푸른 수염의 아내       LE SSERAFIM (르세라핌)
# 45  Genie  46                                    너의 모든 순간                      성시경
# 46  Genie  47                                        연애편지                      임영웅
# 47  Genie  48                             입술 (Feat. 10CM)              헤이즈 (Heize)
# 48  Genie  49                                사랑하지 않아서 그랬어                      임한별
# 49  Genie  50                                       Spicy                    aespa

# %%
pd_data.to_excel('genie.xlsx', index=False)
